# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns
import re
import statistics as stats
# set the graphs to show in the jupyter notebook
# %matplotlib inline

# set seabor graphs to a better style
sns.set(style="ticks")

# %%
Url=("D:\data sciencce\practical 9 lab\IRIS.csv")
iris= pd.read_csv(Url)
iris.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
x=iris["sepal_length"]
print(x)
plt.hist(x, bins=10)
plt.show()
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
x=iris["sepal_width"]
print(x)
plt.hist(x, bins=10)
plt.show()
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
x=iris["petal_length"]
print(x)
plt.hist(x, bins=10)
plt.show()
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: petal_length, Length: 150, dtype: float64

# %%
x=iris["petal_width"]
print(x)
plt.hist(x, bins=10)
plt.show()
# Out:
# 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
#       ...
# 145    2.3
# 146    1.9
# 147    2.0
# 148    2.3
# 149    1.8
# Name: petal_width, Length: 150, dtype: float64

# %% [markdown]
# #WHY DO I NEED BOXPLOT??????????#
# HOW TO READ BOXPLOT????

# %%
b_plot = iris.boxplot(column = 'sepal_length') 
b_plot.plot()
# Out:
# []

# %%
b_plot = iris.boxplot(column = 'sepal_width') 
b_plot.plot()
# Out:
# []

# %%
b_plot = iris.boxplot(column = 'petal_length') 
b_plot.plot()
# Out:
# []

# %%
b_plot = iris.boxplot(column = 'petal_width') 
b_plot.plot()
# Out:
# []

# %%
species_dict = {'Iris-setosa': 0,'Iris-versicolor': 1,'Iris-virginica': 2}
iris['species'] = iris['species'].replace(species_dict)
print(iris['species'])
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: species, Length: 150, dtype: int64

# %%
x=[iris['species']]
print(x)
plt.xlabel(
'species'
)
plt.ylabel(
'requency'
)
plt.hist(x, bins=10)
plt.show()
# Out:
# [0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: species, Length: 150, dtype: int64]

# %%
sns.boxplot(x="sepal_length", y="sepal_width",  data=iris)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>
